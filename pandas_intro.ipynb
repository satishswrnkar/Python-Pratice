# %%
import pandas as pd
import numpy as np

from IPython.display import display

# %% [markdown]
# ## Data Structures in Pandas:
# 1. Series
# 2. DataFrame
# 3. Panel

# %% [markdown]
# ### Series
# 1. Empty Series
# 2. Converting arrays, lists, dictionaries etc to series

# %% [markdown]
# #### 1. Empty Series

# %%
pd.Series([data, index, dtype])

# %%
s = pd.Series()
print(s, type(s))
# Out:
# Series([], dtype: float64) <class 'pandas.core.series.Series'>
# /var/folders/vy/6lqnd0ms07g9y2m78gzj8kw00000gq/T/ipykernel_47848/202694026.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.Series()

# %% [markdown]
# #### 2. Converting arrays, lists, dictionaries etc to series

# %%
s = pd.Series([1.5,2,3,4], index=['a','b','c','d'], dtype = int)
print(s, type(s))
# Out:
# a    1.5
# b    2.0
# c    3.0
# d    4.0
# dtype: float64 <class 'pandas.core.series.Series'>

# %%
s = pd.Series([1,2,3,4], index=['a','b','c','d'], dtype = float)
print('Series from list ')
print(s, type(s))

s = pd.Series(np.array([1,2,3,4]))
print('\nSeries from numpy array ')
print(s, type(s))

d = {
    'a':1,
    'b':2,
    'c':3
}
s = pd.Series(d)
print('\nSeries from dictionary ')
print(s, type(s))
# Out:
# Series from list
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64 <class 'pandas.core.series.Series'>
#
# Series from numpy array
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64 <class 'pandas.core.series.Series'>
#
# Series from dictionary
# a    1
# b    2
# c    3
# dtype: int64 <class 'pandas.core.series.Series'>

# %% [markdown]
# ### DataFrame

# %%
#pd.DataFrame(data, index, columns, dtype)

# %%
df = pd.DataFrame()
print(df, type(df))

# %% [markdown]
# #### Creating a dataframe:
# 1. Array to dataframe
# 2. List to dataframe
# 3. Dictionary to dataframe
# 4. Series to dataframe

# %%
# s = pd.Series([1,2,3,4], index=['a','b','c','d'], dtype = float)
# s = pd.Series(np.array([1,2,3,4]))
d = {
    'a':1,
    'b':2,
    'c':3
}
s = pd.Series(d)
df = pd.DataFrame(s, columns= ['A'])
display(df)
print(type(df))
# Out:
#    A
# a  1
# b  2
# c  3
# <class 'pandas.core.frame.DataFrame'>

# %%
# arr = [['Andy', 25], ['John', 30], ['Robert', 35]]
# arr_1 = np.array([['Andy', 25], ['John', 30], ['Robert', 35]], dtype='str')
# print(arr_1, arr_1.shape)

# df = pd.DataFrame(arr, columns=['Name','Age'], index = ['P1', 'P2', 'P3'])
# display(df)

d = {
    'Show': ('BB', 'BCS','Narcos', 'GOT'),
    'Rating': [10,20,30,-40]
}
print(d)
df = pd.DataFrame(d)
display(df)
# Out:
# {'Show': ('BB', 'BCS', 'Narcos', 'GOT'), 'Rating': [10, 20, 30, -40]}
#      Show  Rating
# 0      BB      10
# 1     BCS      20
# 2  Narcos      30
# 3     GOT     -40

# %% [markdown]
# ### Merge, Join and Concatenate

# %% [markdown]
# #### 1.Merge

# %%
left_df = pd.DataFrame({
    'Alphabet':['a', 'b', 'c', 'd', 'e', 'f'],
    'Number_left':['1','2','3','4', '5', '6'],
    'Alpha_numeric_left':['a1', 'b1', 'c1', 'd1', 'e5', 'f6']
    })
display(left_df)
right_df = pd.DataFrame({
    'Alphabet':['a', 'b', 'c', 'd','g'],
    'Number_right':['5','6','7','8', '10'],
    'Alpha_numeric_right':['e5', 'f6', 'g7', 'h8', 'i10']
    }) 
display(right_df)

merged_df = pd.merge(left_df, right_df, on = 'Alphabet', how = 'inner')
print('Inner join')
display(merged_df)

merged_df = pd.merge(left_df, right_df, on = 'Alphabet', how = 'left')
print('\nLeft join')
display(merged_df)

merged_df = pd.merge(left_df, right_df, on = 'Alphabet', how = 'right')
print('\nRight join')
display(merged_df)

merged_df = pd.merge(left_df, right_df, on = 'Alphabet', how = 'outer')
print('\nOuter join')
display(merged_df)
# Out:
#   Alphabet Number_left Alpha_numeric_left
# 0        a           1                 a1
# 1        b           2                 b1
# 2        c           3                 c1
# 3        d           4                 d1
# 4        e           5                 e5
# 5        f           6                 f6
#   Alphabet Number_right Alpha_numeric_right
# 0        a            5                  e5
# 1        b            6                  f6
# 2        c            7                  g7
# 3        d            8                  h8
# 4        g           10                 i10
# Inner join
#   Alphabet Number_left Alpha_numeric_left Number_right Alpha_numeric_right
# 0        a           1                 a1            5                  e5
# 1        b           2                 b1            6                  f6
# 2        c           3                 c1            7                  g7
# 3        d           4                 d1            8                  h8
# Left join
#   Alphabet Number_left Alpha_numeric_left Number_right Alpha_numeric_right
# 0        a           1                 a1            5                  e5
# 1        b           2                 b1            6                  f6
# 2        c           3                 c1            7                  g7
# 3        d           4                 d1            8                  h8
# 4        e           5                 e5          NaN                 NaN
# 5        f           6                 f6          NaN                 NaN
# Right join
#   Alphabet Number_left Alpha_numeric_left Number_right Alpha_numeric_right
# 0        a           1                 a1            5                  e5
# 1        b           2                 b1            6                  f6
# 2        c           3                 c1            7                  g7
# 3        d           4                 d1            8                  h8
# 4        g         NaN                NaN           10                 i10
# Outer join
#   Alphabet Number_left Alpha_numeric_left Number_right Alpha_numeric_right
# 0        a           1                 a1            5                  e5
# 1        b           2                 b1            6                  f6
# 2        c           3                 c1            7                  g7
# 3        d           4                 d1            8                  h8
# 4        e           5                 e5          NaN                 NaN
# 5        f           6                 f6          NaN                 NaN
# 6        g         NaN                NaN           10                 i10

# %%
df1 = pd.DataFrame({'name':['Julie']*3, 'age':10+np.arange(3)}, index = ['a'+str(_) for _ in range(3)])
print('1st dataframe')
display(df1)
df2 = pd.DataFrame({'name':['John', 'Andy']*2, 'age':20+np.arange(4)}, index = ['b'+str(_) for _ in range(4)])
print('\n2nd dataframe')
display(df2)
df3 = pd.DataFrame({'name':['Williams']*5, 'age':30+np.arange(5)}, index = ['c'+str(_) for _ in range(5)])
print('\n3rd dataframe')
display(df3)
print('\nAfter concatenating')
display(pd.concat([df1, df2, df3], ignore_index = True, axis = 0))
# Out:
# 1st dataframe
#      name  age
# a0  Julie   10
# a1  Julie   11
# a2  Julie   12
# 2nd dataframe
#     name  age
# b0  John   20
# b1  Andy   21
# b2  John   22
# b3  Andy   23
# 3rd dataframe
#         name  age
# c0  Williams   30
# c1  Williams   31
# c2  Williams   32
# c3  Williams   33
# c4  Williams   34
# After concatenating
#         name  age
# 0      Julie   10
# 1      Julie   11
# 2      Julie   12
# 3       John   20
# 4       Andy   21
# 5       John   22
# 6       Andy   23
# 7   Williams   30
# 8   Williams   31
# 9   Williams   32
# 10  Williams   33
# 11  Williams   34

# %%
df1 = pd.DataFrame({'Key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'], 'data1': range(7)})
print('1st dataframe')
display(df1)
df2 = pd.DataFrame({'Key': ['a', 'b', 'd'], 'data2': range(3)})
print('\n2nd dataframe')
display(df2)
print('\nAfter concatenating dataframe')
print('\nAfter concatenating')
display(pd.concat([df1, df2], axis = 0, ignore_index = False))
# Out:
# 1st dataframe
#   Key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6
# 2nd dataframe
#   Key  data2
# 0   a      0
# 1   b      1
# 2   d      2
# After concatenating dataframe
#
# After concatenating
#   Key  data1  data2
# 0   b    0.0    NaN
# 1   b    1.0    NaN
# 2   a    2.0    NaN
# 3   c    3.0    NaN
# 4   a    4.0    NaN
# 5   a    5.0    NaN
# 6   b    6.0    NaN
# 0   a    NaN    0.0
# 1   b    NaN    1.0
# 2   d    NaN    2.0

# %% [markdown]
# ## Hands on with Real Life Data

# %%
df_cars = pd.read_csv('mtcars2.csv')
#display(df_cars)

# %% [markdown]
# ### Getting idea about the data

# %%
#check the type
print(type(df_cars))

#view number of rows and columns in the dataframe
print(df_cars.shape)

#view only the first n records
# here n is 5 
display(df_cars.head(5))

#view only the last n records
# here n is 5 
display(df_cars.tail(5))

# random n many recors
# here n = 5
display(df_cars.sample(7))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (32, 13)
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2
#     S.No      Unnamed: 1   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  \
# 27    28    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1
# 28    29  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1
# 29    30    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1
# 30    31   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1
# 31    32      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1
#
#     gear  carb
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2
#     S.No        Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 6      7        Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 21    22  Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 25    26         Fiat X1-9  27.3    4   79.0   66  4.08  1.935    NaN   1   1
# 12    13        Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 8      9          Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 30    31     Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 26    27     Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
#
#     gear  carb
# 6      3     4
# 21     3     2
# 25     4     1
# 12     3     3
# 8      4     2
# 30     5     8
# 26     5     2

# %%
# print a concise summary of the columns
display(df_cars.info(null_counts = True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.No        32 non-null     int64
#  1   Unnamed: 1  32 non-null     object
#  2   mpg         32 non-null     float64
#  3   cyl         32 non-null     int64
#  4   disp        32 non-null     float64
#  5   hp          32 non-null     int64
#  6   drat        32 non-null     float64
#  7   wt          32 non-null     float64
#  8   qsec        29 non-null     float64
#  9   vs          32 non-null     int64
#  10  am          32 non-null     int64
#  11  gear        32 non-null     int64
#  12  carb        32 non-null     int64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 3.4+ KB
# /var/folders/vy/6lqnd0ms07g9y2m78gzj8kw00000gq/T/ipykernel_48058/3295875182.py:2: FutureWarning: null_counts is deprecated. Use show_counts instead
#   df_cars.info(null_counts = True)

# %%
## what columns are there
print(df_cars.columns)
type(df_cars.columns)
# Out:
# Index(['S.No', 'Unnamed: 1', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec',
#        'vs', 'am', 'gear', 'carb'],
#       dtype='object')
# pandas.core.indexes.base.Index

# %%
## selecting a dataframe with asubset of teh columns
subset_col_list = ['S.No', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec',
       'vs', 'am', 'gear', 'carb']
df_cars_sub = df_cars[subset_col_list]
df_cars_sub.shape
# Out:
# (32, 12)
